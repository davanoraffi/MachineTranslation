# %% [markdown]
# # Load Data

# %%
# !pip install datasets -qq

# %%
from datasets import load_dataset

dataset = load_dataset("haryoaw/stif-indonesia")

# %%
import pandas as pd

df_train = pd.DataFrame(dataset['train'])
df_test = pd.DataFrame(dataset['test'])
df_dev = pd.DataFrame(dataset['dev'])

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# # Preprocessing

# %%
import re
import string
from nltk.tokenize import word_tokenize

def preprocess_sentence(sentence):
    sentence = sentence.lower()
    sentence = re.sub(r'@\S+', '', sentence)
    sentence = re.sub(r'http\S+', '', sentence)
    sentence = re.sub(r'pic.\S+', '', sentence)
    sentence = re.sub(r"[^a-zA-ZáéíóúÁÉÍÓÚ']", ' ', sentence)
    sentence = re.sub(r'\s+[a-zA-ZáéíóúÁÉÍÓÚ]\s+', ' ', sentence + ' ')
    sentence = "".join([i for i in sentence if i not in string.punctuation])
    words = word_tokenize(sentence)
    sentence = " ".join(words)
    sentence = re.sub("\s[\s]+", " ", sentence).strip()
    sentence = re.sub("\s[\s]+", " ", sentence).strip()
    return sentence


# Menggunakan fungsi pada kolom informal dan formal
df_train['informal'] = df_train['informal'].apply(preprocess_sentence)
df_train['formal'] = df_train['formal'].apply(preprocess_sentence)

df_test['informal'] = df_test['informal'].apply(preprocess_sentence)
df_test['formal'] = df_test['formal'].apply(preprocess_sentence)

df_dev['informal'] = df_dev['informal'].apply(preprocess_sentence)
df_dev['formal'] = df_dev['formal'].apply(preprocess_sentence)

# %%
# Fungsi untuk menghapus pola tertentu
def remove_patterns(text):
    # Menghapus pola xxxuserxxx dan xxxnumberxxx
    text_cleaned = re.sub(r'xxxuserxxx|xxxnumberxxx|xxxphonexxx|xxxdatexxx|xxxmoneyxxx|xxxemailxxx|xxxpercentxxx|xxxtimexxx', '', text)
    return text_cleaned

# Menggunakan fungsi pada kolom informal dan formal
df_train['informal'] = df_train['informal'].apply(remove_patterns)
df_train['formal'] = df_train['formal'].apply(remove_patterns)

df_test['informal'] = df_test['informal'].apply(remove_patterns)
df_test['formal'] = df_test['formal'].apply(remove_patterns)

df_dev['informal'] = df_dev['informal'].apply(remove_patterns)
df_dev['formal'] = df_dev['formal'].apply(remove_patterns)

# %%
df_train
# Out:
#                                                informal  \
# 0     alhamdulillah stlh libur  hari onbid lgsg dika...
# 1     selamat sore min saya mau pesan tiket ka via w...
# 2     iya kak terimakasih tapi tadi sudah datang ke ...
# 3     malam min   situs kalian error ya mau order da...
# 4     min pembelian token pln apa ada kendala ini bl...
# ...                                                 ...
# 1917  halo bni ini maintenance banking nya selesai k...
# 1918  malam mau komplain paket statusnya sudah sampa...
# 1919  sepertinya merchant emang sengaja pada gak mau...
# 1920            yaallah kaka kelas sma gua viral anjerr
# 1921     kalo paket iphone plan harganya sesuai zona ga
#
#                                                  formal
# 0     alhamdulillah setelah libur  hari onbid langsu...
# 1     selamat sore admin saya mau pesan tiket ka via...
# 2     iya kak terima kasih tetapi tadi sudah datang ...
# 3     malam admin   apakah situs kalian error mau or...
# 4     admin pembelian token pln apa ada kendala ini ...
# ...                                                 ...
# 1917  halo bni ini maintenance bankingnya selesai kapan
# 1918  malam saya mau komplain paket statusnya sudah ...
# 1919  sepertinya merchant memang sengaja tidak mau m...
# 1920                ya allah kakak kelas sma saya viral
# 1921  kalau paket iphone rencana harganya sesuai zon...
#
# [1922 rows x 2 columns]

# %%
df_test
# Out:
#                                               informal  \
# 0                    belum ada konfirmasi lagi kah min
# 1    matiin notif yg itu kmrn jg sampah bgt notif g...
# 2    kak untuk keluhan telkomsel silahkan konfirmas...
# 3    another attempted fraud potensi penipuan atas ...
# 4                tolong dong udah   kayagini kenapa ya
# ..                                                 ...
# 358               kok malah tambah lemot jaringan saya
# 359  halo sat  lagi ada troble apani mau paketin ye...
# 360  min tolong cek dm saya terkait keluhan paket saya
# 361  halo admin  paket eg kr sudh sampai mana track...
# 362  hai  daftar transfer ke bank btn kok invalid t...
#
#                                                 formal
# 0                   belum ada konfirmasi lagikah admin
# 1    matikan notifikasi yang itu kemarin juga sampa...
# 2    kak untuk keluhan telkomsel silahkan konfirmas...
# 3    percobaan penipuan lainnya potensi penipuan at...
# 4                      tolong sudah seperti ini kenapa
# ..                                                 ...
# 358          mengapa malah tambah lambat jaringan saya
# 359  halo  sedang ada masalah apakah mau membeli pa...
# 360  admin tolong periksa dm saya terkait keluhan p...
# 361  halo admin  paket  sudah sampai mana pelacakan...
# 362  hai  daftar transfer ke bank btn mengapa tidak...
#
# [363 rows x 2 columns]

# %%
df_dev
# Out:
#                                               informal  \
# 0    kalian juga tdk banyak membantu terkait dengan...
# 1         kan akun lu private jd kaga bisa liat mereka
# 2    min kenapa akun saya tidak ditemukan ya apakah...
# 3    akun sy sdh premium tolong cashback yg seharus...
# 4                            tolong cek dm yaa min thx
# ..                                                 ...
# 209  saya salah pilihan isi resi harusnya otomatis ...
# 210  tfr ke rek rdn dari jum at siang sampe sekaran...
# 211  oh iyaa pak eko kalo  gue pake modem andromax ...
# 212  gojek sepersepuluh hidupku makasih gojek telah...
# 213  saya isi gopay belum masuk min saya sangat kec...
#
#                                                 formal
# 0    kalian juga tidak banyak membantu terkait deng...
# 1    kan akun kamu private jadi mereka tidak bisa l...
# 2    admin mengapa akun saya tidak ditemukan apakah...
# 3    akun saya sudah premium tolong cashback yang s...
# 4                   tolong periksa dm min terima kasih
# ..                                                 ...
# 209  saya salah pilihan isi resi harusnya otomatis ...
# 210  transfer ke rekening rdn dari jumat siang samp...
# 211  oh iya pak eko kalau  saya pakai modem androma...
# 212  gojek sepersepuluh hidupku terima kasih gojek ...
# 213  saya isi gopay belum masuk admin saya sangat k...
#
# [214 rows x 2 columns]

# %%
import pandas as pd

X_train = df_train['informal']
y_train = df_train['formal']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Inisialisasi Tokenizer untuk teks formal
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# Konversi teks formal ke urutan angka
X_train_seq = tokenizer.texts_to_sequences(X_train)

# Padding urutan angka untuk teks formal
X_train_padded = pad_sequences(X_train_seq)

# Inisialisasi Tokenizer untuk label
tokenizer_y = Tokenizer()
tokenizer_y.fit_on_texts(y_train)

# Konversi teks ke urutan angka untuk label
y_train_seq = tokenizer_y.texts_to_sequences(y_train)

# Padding urutan angka untuk label
y_train_padded = pad_sequences(y_train_seq, maxlen=X_train_padded.shape[1])

# %% [markdown]
# # Modelling LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Inisialisasi model
model = Sequential()

# Layer embedding
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=100000, input_length=X_train_padded.shape[1]))

# Layer LSTM
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.5))

# Layer output dengan jumlah kelas sesuai dengan label
model.add(Dense(len(tokenizer_y.word_index) + 1, activation='softmax'))

# Kompilasi model dengan learning rate yang berbeda
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Tampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 27, 100000)        436900000
#
#  lstm (LSTM)                 (None, 27, 512)           205850624
#
#  dropout (Dropout)           (None, 27, 512)           0
#
#  dense (Dense)               (None, 27, 3402)          1745226
#
# =================================================================
# Total params: 644495850 (2.40 GB)
# Trainable params: 644495850 (2.40 GB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
num_unique_words = len(tokenizer.word_index) + 1
print("Jumlah unik kata:", num_unique_words)
# Out:
# Jumlah unik kata: 4369

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Define EarlyStopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with EarlyStopping
history = model.fit(X_train_padded, y_train_padded, epochs=300, batch_size=32, validation_split=0.2, callbacks=[early_stopping])
# Out:
# Epoch 1/300
# 49/49 [==============================] - 44s 710ms/step - loss: 3.1666 - accuracy: 0.5828 - val_loss: 2.5893 - val_accuracy: 0.6468
# Epoch 2/300
# 49/49 [==============================] - 29s 589ms/step - loss: 2.4274 - accuracy: 0.6560 - val_loss: 2.3805 - val_accuracy: 0.6772
# Epoch 3/300
# 49/49 [==============================] - 28s 573ms/step - loss: 2.0846 - accuracy: 0.6925 - val_loss: 2.2521 - val_accuracy: 0.6929
# Epoch 4/300
# 49/49 [==============================] - 29s 596ms/step - loss: 1.7953 - accuracy: 0.7191 - val_loss: 2.1769 - val_accuracy: 0.7006
# Epoch 5/300
# 49/49 [==============================] - 29s 604ms/step - loss: 1.5440 - accuracy: 0.7440 - val_loss: 2.1284 - val_accuracy: 0.7067
# Epoch 6/300
# 49/49 [==============================] - 29s 599ms/step - loss: 1.3305 - accuracy: 0.7653 - val_loss: 2.1013 - val_accuracy: 0.7110
# Epoch 7/300
# 49/49 [==============================] - 29s 596ms/step - loss: 1.1457 - accuracy: 0.7918 - val_loss: 2.0827 - val_accuracy: 0.7114
# Epoch 8/300
# 49/49 [==============================] - 26s 523ms/step - loss: 0.9873 - accuracy: 0.8112 - val_loss: 2.0879 - val_accuracy: 0.7098
# Epoch 9/300
# 49/49 [==============================] - 27s 544ms/step - loss: 0.8594 - accuracy: 0.8258 - val_loss: 2.0910 - val_accuracy: 0.7111
# Epoch 10/300
# 49/49 [==============================] - 26s 532ms/step - loss: 0.7540 - accuracy: 0.8401 - val_loss: 2.0941 - val_accuracy: 0.7106
# Epoch 11/300
# 49/49 [==============================] - 27s 552ms/step - loss: 0.6766 - accuracy: 0.8521 - val_loss: 2.1079 - val_accuracy: 0.7111
# Epoch 12/300
# 49/49 [==============================] - 27s 552ms/step - loss: 0.6232 - accuracy: 0.8618 - val_loss: 2.1196 - val_accuracy: 0.7108
# Epoch 13/300
# 49/49 [==============================] - 27s 549ms/step - loss: 0.5888 - accuracy: 0.8679 - val_loss: 2.1255 - val_accuracy: 0.7085
# Epoch 14/300
# 49/49 [==============================] - 26s 541ms/step - loss: 0.5681 - accuracy: 0.8739 - val_loss: 2.1415 - val_accuracy: 0.7067
# Epoch 15/300
# 49/49 [==============================] - 27s 542ms/step - loss: 0.5411 - accuracy: 0.8789 - val_loss: 2.1561 - val_accuracy: 0.7064
# Epoch 16/300
# 49/49 [==============================] - 27s 555ms/step - loss: 0.5160 - accuracy: 0.8854 - val_loss: 2.1676 - val_accuracy: 0.7050
# Epoch 17/300
# 49/49 [==============================] - 29s 604ms/step - loss: 0.5047 - accuracy: 0.8881 - val_loss: 2.1839 - val_accuracy: 0.7045

# %% [markdown]
# # Predicting

# %%
# Tokenisasi teks informal pada data pengujian
X_dev_seq = tokenizer.texts_to_sequences(df_dev['informal'])
X_dev_padded = pad_sequences(X_dev_seq, maxlen=X_train_padded.shape[1])

# Lakukan prediksi
predicted_sequences = model.predict(X_dev_padded)

# Ambil indeks kelas dengan nilai probabilitas tertinggi untuk setiap langkah waktu
predicted_classes = predicted_sequences.argmax(axis=-1)

# Konversi indeks kelas kembali ke teks formal
predicted_texts = tokenizer_y.sequences_to_texts(predicted_classes)
# Out:
# 7/7 [==============================] - 1s 134ms/step

# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

# Tokenisasi teks formal pada data pengujian
y_dev_seq = tokenizer_y.texts_to_sequences(df_dev['formal'])
y_dev_padded = pad_sequences(y_dev_seq, maxlen=X_train_padded.shape[1])

# Ambil indeks kelas dengan nilai probabilitas tertinggi untuk setiap langkah waktu
predicted_classes = predicted_sequences.argmax(axis=-1)

# Konversi indeks kelas kembali ke teks formal
predicted_texts = tokenizer_y.sequences_to_texts(predicted_classes)

# Tokenisasi teks formal pada data pengujian
references = tokenizer_y.sequences_to_texts(y_dev_seq)

# Tokenisasi teks formal yang diprediksi
hypotheses = tokenizer_y.sequences_to_texts(predicted_classes)

# Hitung BLEU score untuk setiap kalimat
bleu_scores = [sentence_bleu([ref.split()], hyp.split()) for ref, hyp in zip(references, hypotheses)]

# Hitung BLEU score untuk seluruh corpus
corpus_bleu_score = corpus_bleu([[ref.split()] for ref in references], [hyp.split() for hyp in hypotheses])

print("BLEU Scores for Each Sentence:")
for i, score in enumerate(bleu_scores, start=1):
    print(f"Sentence {i}: {score:.4f}")

print("\nCorpus BLEU Score:", corpus_bleu_score)
# Out:
# BLEU Scores for Each Sentence:
# Sentence 1: 0.7964
# Sentence 2: 0.0000
# Sentence 3: 0.4250
# Sentence 4: 0.5334
# Sentence 5: 0.0000
# Sentence 6: 0.0000
# Sentence 7: 0.0000
# Sentence 8: 0.0000
# Sentence 9: 0.6606
# Sentence 10: 0.2622
# Sentence 11: 0.0000
# Sentence 12: 0.5373
# Sentence 13: 0.5828
# Sentence 14: 0.5460
# Sentence 15: 0.0000
# Sentence 16: 0.0000
# Sentence 17: 0.0000
# Sentence 18: 0.4740
# Sentence 19: 0.6407
# Sentence 20: 0.0000
# Sentence 21: 0.3453
# Sentence 22: 0.6148
# Sentence 23: 0.4548
# Sentence 24: 0.0000
# Sentence 25: 0.4061
# Sentence 26: 0.7598
# Sentence 27: 0.0000
# Sentence 28: 0.0000
# Sentence 29: 0.4500
# Sentence 30: 0.6148
# Sentence 31: 0.0000
# Sentence 32: 0.5918
# Sentence 33: 0.0000
# Sentence 34: 0.5342
# Sentence 35: 0.0000
# Sentence 36: 0.0000
# Sentence 37: 0.0000
# Sentence 38: 0.5306
# Sentence 39: 0.7017
# Sentence 40: 0.0000
# Sentence 41: 0.0000
# Sentence 42: 0.1805
# Sentence 43: 0.4238
# Sentence 44: 0.7366
# Sentence 45: 0.0000
# Sentence 46: 0.0000
# Sentence 47: 0.2669
# Sentence 48: 0.0000
# Sentence 49: 0.0000
# Sentence 50: 0.0000
# Sentence 51: 0.0000
# Sentence 52: 0.0000
# Sentence 53: 0.4572
# Sentence 54: 0.0000
# Sentence 55: 0.0000
# Sentence 56: 0.6753
# Sentence 57: 0.3814
# Sentence 58: 0.0000
# Sentence 59: 0.8187
# Sentence 60: 0.4347
# Sentence 61: 0.2481
# Sentence 62: 0.0000
# Sentence 63: 0.0000
# Sentence 64: 0.5452
# Sentence 65: 0.0000
# Sentence 66: 0.0000
# Sentence 67: 0.0000
# Sentence 68: 0.4739
# Sentence 69: 0.5648
# Sentence 70: 0.2908
# Sentence 71: 0.7890
# Sentence 72: 0.0000
# Sentence 73: 1.0000
# Sentence 74: 0.7506
# Sentence 75: 0.3415
# Sentence 76: 0.0000
# Sentence 77: 0.4895
# Sentence 78: 0.0000
# Sentence 79: 0.0000
# Sentence 80: 0.0000
# Sentence 81: 0.0000
# Sentence 82: 1.0000
# Sentence 83: 0.2956
# Sentence 84: 0.1737
# Sentence 85: 0.1999
# Sentence 86: 0.0000
# Sentence 87: 0.0000
# Sentence 88: 0.3913
# Sentence 89: 0.0000
# Sentence 90: 0.0000
# Sentence 91: 0.7673
# Sentence 92: 0.4281
# Sentence 93: 0.2328
# Sentence 94: 1.0000
# Sentence 95: 0.4049
# Sentence 96: 0.1385
# Sentence 97: 0.0000
# Sentence 98: 0.2318
# Sentence 99: 0.0000
# Sentence 100: 0.3706
# Sentence 101: 0.6704
# Sentence 102: 0.0000
# Sentence 103: 0.4111
# Sentence 104: 0.0000
# Sentence 105: 0.0000
# Sentence 106: 0.6105
# Sentence 107: 0.8465
# Sentence 108: 0.0000
# Sentence 109: 0.0000
# Sentence 110: 0.2597
# Sentence 111: 0.0000
# Sentence 112: 0.6385
# Sentence 113: 0.6687
# Sentence 114: 0.0000
# Sentence 115: 0.0000
# Sentence 116: 0.8633
# Sentence 117: 0.1373
# Sentence 118: 0.0000
# Sentence 119: 0.3768
# Sentence 120: 0.5912
# Sentence 121: 0.0000
# Sentence 122: 0.4824
# Sentence 123: 0.2898
# Sentence 124: 0.0000
# Sentence 125: 0.4265
# Sentence 126: 0.0000
# Sentence 127: 0.0000
# Sentence 128: 0.0000
# Sentence 129: 0.0000
# Sentence 130: 0.0000
# Sentence 131: 0.0000
# Sentence 132: 0.0000
# Sentence 133: 0.4153
# Sentence 134: 0.0000
# Sentence 135: 0.5133
# Sentence 136: 0.7122
# Sentence 137: 0.0000
# Sentence 138: 0.0000
# Sentence 139: 0.0000
# Sentence 140: 0.6186
# Sentence 141: 0.2947
# Sentence 142: 0.0000
# Sentence 143: 0.0000
# Sentence 144: 0.1394
# Sentence 145: 0.4671
# Sentence 146: 0.4375
# Sentence 147: 0.0000
# Sentence 148: 0.4775
# Sentence 149: 0.4137
# Sentence 150: 0.2561
# Sentence 151: 0.0000
# Sentence 152: 0.0000
# Sentence 153: 0.4842
# Sentence 154: 0.0000
# Sentence 155: 0.0000
# Sentence 156: 0.0000
# Sentence 157: 0.7598
# Sentence 158: 0.3850
# Sentence 159: 0.3102
# Sentence 160: 0.0000
# Sentence 161: 0.0000
# Sentence 162: 0.2635
# Sentence 163: 0.2708
# Sentence 164: 0.0000
# Sentence 165: 0.0000
# Sentence 166: 0.4950
# Sentence 167: 0.4299
# Sentence 168: 0.3966
# Sentence 169: 0.0000
# Sentence 170: 0.0000
# Sentence 171: 0.0000
# Sentence 172: 0.0000
# Sentence 173: 0.0000
# Sentence 174: 0.7421
# Sentence 175: 0.0000
# Sentence 176: 0.2390
# Sentence 177: 0.0000
# Sentence 178: 0.0000
# Sentence 179: 0.0000
# Sentence 180: 0.0000
# Sentence 181: 0.0000
# Sentence 182: 0.0000
# Sentence 183: 0.0000
# Sentence 184: 0.0000
# Sentence 185: 0.8242
# Sentence 186: 0.2195
# Sentence 187: 0.0000
# Sentence 188: 0.0000
# Sentence 189: 0.0000
# Sentence 190: 0.0000
# Sentence 191: 0.6435
# Sentence 192: 0.0000
# Sentence 193: 0.4683
# Sentence 194: 0.5782
# Sentence 195: 0.0000
# Sentence 196: 0.0000
# Sentence 197: 0.5475
# Sentence 198: 0.0000
# Sentence 199: 0.0000
# Sentence 200: 0.0000
# Sentence 201: 1.0000
# Sentence 202: 0.5038
# Sentence 203: 0.4842
# Sentence 204: 0.0000
# Sentence 205: 0.0000
# Sentence 206: 0.1967
# Sentence 207: 0.0000
# Sentence 208: 0.4698
# Sentence 209: 0.0000
# Sentence 210: 0.0000
# Sentence 211: 0.4734
# Sentence 212: 0.2102
# Sentence 213: 0.0000
# Sentence 214: 0.7911
#
# Corpus BLEU Score: 0.3621338627237194
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 4-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 2-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)
# /usr/local/lib/python3.10/dist-packages/nltk/translate/bleu_score.py:552: UserWarning:
# The hypothesis contains 0 counts of 3-gram overlaps.
# Therefore the BLEU score evaluates to 0, independently of
# how many N-gram overlaps of lower order it contains.
# Consider using lower n-gram order or use SmoothingFunction()
#   warnings.warn(_msg)

# %%
# Tokenisasi teks informal pada data uji
X_test_seq = tokenizer.texts_to_sequences(df_test['informal'])
X_test_padded = pad_sequences(X_test_seq, maxlen=X_train_padded.shape[1])

# Lakukan prediksi
predicted_sequences_test = model.predict(X_test_padded)

# Ambil indeks kelas dengan nilai probabilitas tertinggi untuk setiap langkah waktu
predicted_classes_test = predicted_sequences_test.argmax(axis=-1)

# Konversi indeks kelas kembali ke teks formal
predicted_texts_test = tokenizer_y.sequences_to_texts(predicted_classes_test)
# Out:
# 12/12 [==============================] - 2s 135ms/step

# %%
predicted_texts
# Out:
# ['juga tidak banyak membantu terkait dengan jaringan kalian yang terima',
#  'akun kamu jadi tidak bisa bisa tidak',
#  'admin mengapa akun saya tidak bagaimana bagaimana apakah admin saya punya akun saya',
#  'akun saya sudah sudah tolong cashback yang bayar saya dapat untuk transaksi tanggal segera',
#  'tolong cek dm dm admin kasih',
#  'lalu saya beli paket sudah bayar sudah tapi tetapi sampai sekarang belum masih dalam berapa ya sudah seminggu',
#  'order saya saya belum sampai tujuan sampai tanggal belum ini resinya',
#  'tolong balas dm saya admin',
#  'admin admin bonus pulsanya bisa untuk paket data tidak tidak',
#  'juga admin kasih sudah respons rumah di ada saja admin tidak ada yang terima terima juga tidak ada yang namanya',
#  'aku sekali',
#  'saya pernah seperti ini ini sadar',
#  'sudah hari status belum juga berubah hari admin tadi sudah telepon katanya hanya suruh menunggu',
#  'ayo di pelanggan indosat yang suka yang pulsanya atau sinyal jelek ayo pindah ke',
#  'ini tahu serasa tidak di sama kfc',
#  'kalau es terus',
#  'kuota dm tapi tidak di direspons',
#  'iya ini belum sudah dm',
#  'tolong paket saya nomor resi jp saya ini saja sudah hari',
#  'saya melakukan transaksinya via mesin atm kak',
#  'sudah banyak sekali yang yang mungkin bisa jadi resi ke hahaha',
#  'itu kode promonya ada di di di',
#  'balas dm dari pagi di dm',
#  'aku pernah begitu terpotong tapi dia nanti seperti lagi kalau masih berapa',
#  'cara cara ke akun bagaimana saya tetap tidak mengerti padahal sudah sudah terima hahaha',
#  'sudah saya dm tolong segera direspons',
#  'admin admin admin admin admin sudah sudah periksa ke belum belum juga',
#  'dia sudah sudah jadi saja tidak hanya mencari periksa provider',
#  'admin saya naik grab sudah saya bayar pakai ovo ovo saat turun saya bayar jangan lagi cara ovonya agar terima bagaimana bagaimana',
#  'selamat malam admin tolong cek dm dari saya terkait ke up via kasih',
#  'menunggu grab grabfood datang',
#  'admin sudah dua hari atm saya tidak bisa untuk transaksi keterangan seperti ini dengan atm aku',
#  'bagaimana dm nya kak nomor saya',
#  'pengiriman dari jakarta ke jakarta yang waktu berapa lama',
#  'sekali admin mau mau pesawat saja susah susah dari ya dari mau mau bagaimana wa saja saja saja',
#  'mohon maaf kak aplikasi dan ganti nya',
#  'admin admin ini internet internet saya sekali sekali',
#  'kita sama admin dari minggu disuruh dm email sama nomor hp tapi sampai sekarang belum benar belum ini bagaimana bagaimana',
#  'admin kalau unlimited indosat gb itu ada termasuk unlimited juga tidak',
#  'admin admin ovo saya bisa dibuka',
#  'shopee error error mau checkout pakai kartu kartu',
#  'iya saja saja aku juga pernah begitu hanya ini beda saja',
#  'apakah buka menu sudah atau hanya saja',
#  'selamat malam mau konfirmasi bisa tidak kita melakukan pembatalan pesanan tanpa harus karena ini kebetulan saya konsumen yang mau membatalkan',
#  'admin tolong tolong di agar barang bisa di seperti pada di barang lainnya bisa harga harga pengiriman luar',
#  'admin kasih banyak terima',
#  'admin apakah sms kenapa paket akan setelah hari lagi ini agar habis pulsa data',
#  'memang kita semua',
#  'admin tolong tolong yang saya',
#  'mengapa ada ini semakin jadi jadi',
#  'kuota bagaimana bagaimana',
#  'saya beli pulsa pulsa belum masuk masuk',
#  'admin admin admin ada dimana saja ya saya mau beli paket voucher gojek ini',
#  'dm nya bisa bisa admin',
#  'dm pakai dapat dapat nya dapat kopi',
#  'nama saya nomor tidak bisa melakukan paket internet',
#  'pembelian paket internet malam mengapa tidak bisa bisa admin',
#  'saya di tapi tidak',
#  'fitur bpjs kesehatan berada di',
#  'paket paket internet data di apa apa',
#  'ini dari kapan hari mau mau data internet belum bisa kak',
#  'dan',
#  'dm dm dm sudah dikirim kasih',
#  'yang lebih cepat dari gundala yang yang aku lagi ini perjalanan lebih cepat dari gundala',
#  'memang dan paling lebih tapi jaringannya',
#  'admin jam tidak lagi sebanyak',
#  'hp di nomor saya juga paket sinyalnya',
#  'bisa tidak tidak xix vii di dan soalnya sudah minta ke penjual malah tidak bisa bisa katanya',
#  'ini sampai hari ini pengembalian belum juga terima uangnya',
#  'hi admin admin minggu lalu buka buka resi sampai sekarang kenapa belum dapat sms dari bca nya untuk voucher nya',
#  'selamat malam admin saya punya masalah tadi saya transaksi dan sudah melakukan pembayaran tapi status transaksi saya tidak bagaimana mohon mohon kasih',
#  'halo kenapa saya tidak bisa bisa paket unlimited bisa dari kemarin apakah sedang atau',
#  'yang lebih cepat dari gundala gundala naik gundala',
#  'segera kirim pesanan saya sudah lewat dari dari waktu',
#  'saja saya saja barang di tokopedia dan tidak bisa bisa bisa tolong bisa pesanan saya saya xix tolong',
#  'kenapa jadi lambat update update tapi gojek tidak',
#  'admin baru paket dan berakhir hingga tanggal ini mengapa dapat sms baru berakhir hingga tanggal tolong admin',
#  'admin admin paket nomor resi tidak gerak tidak dari tanggal',
#  'hari tidak ada pengiriman ya admin',
#  'admin admin kalau upgrade ke dapat bonus selama bulan bagaimana',
#  'tidak tidak ya saat itu mungkin itu mau ke kantor',
#  'kapan bisa seperti ini',
#  'provider bangsat cm bangsat alias maling dan juga konsumen',
#  'bisa error tidak bisa pulang sudah ganti pembayaran tunai saja tidak bisa',
#  'yang ada di di akhirnya uangnya di refund sama grab sekali kasih',
#  'terblokir solusinya bagaimana',
#  'admin admin di bantu update pengiriman',
#  'maaf mbak apakah admin aku setelah isi saldo gopay di atm tidak tidak masuk masuk',
#  'admin cek dm dm',
#  'aku mau follow kalau admin undang aku kalau tidak tidak mau',
#  'apakah hari ini error karena keluar seperti ini',
#  'admin daerah di sinyal hilang saya restart tetap hilang mohon admin',
#  'akun saya saya saya dari hari jumat sembilan kirim tetap saja masih terima tolong terima tolong saya juga kena',
#  'transaksi pembeli meminta kami untuk membatalkan transaksi ini mohon bantuannya',
#  'admin uang saya saya kalau tidak bisa uang saya yang sudah saya top up up ke gopay dari jawab dan direspons cepat kasih',
#  'malam saya mau barang karena salah kirim kirim harus harus bukti penjual saja dimana dimana kasih',
#  'aku bayar tidak masalahnya yang ada ada bagaimana bagaimana bagaimana kalau yang ada',
#  'kenapa saya pulsa saya padahal tidak ada tidak pulsa tidak ada sms masuk tentang tidak begitu',
#  'tolong tolong sinyalnya untuk main permainan online buruk sekali',
#  'setiap mau pesan grab grabfood hp saya lambat sekali dan jadi jadi tetapi kalau buka grab grabbike lancar lancar',
#  'booth di jogja yang bisa untuk upgrade akun dimana saja saja admin',
#  'ini belum belum saya adminnya mengapa ya kata admin',
#  'selamat siang nomor saya hilang bagaimana bagaimana bagaimana lagi bagaimana',
#  'sudah saya saya malah begitu responnya buat tidak',
#  'bisa mas dapat coba saat sekarang semua lagi gojek ini',
#  'baik berarti harus di bank bca awal ya untuk apakah bisa lebih dari nomor rekening',
#  'admin ada apa dengan jaringan datanya',
#  'internet cepat kuota',
#  'sudah bisa bisa ditanggapi dicoba ulang',
#  'admin promo makan jajan kfc kalau belum cashback nya dapat dapat',
#  'kenapa kenapa sinyalnya jelek sekali ini',
#  'tidak di di saat paket tiba tersebut tidak ada konfirmasi ke sama sekali tidak ada telepon padahal begitu kan',
#  'hahaha dari top menjadi top',
#  'admin admin ini kenapa indosat kenapa bisa paket',
#  'admin apa admin dalam paket unlimited',
#  'sudah dicoba tapi tetap tidak bisa admin bagaimana bagaimana',
#  'bonus pulsa ribu ribu untuk dengan internet menelepon sms saja mengapa tidak paket internet',
#  'kak saya itu apa mengapa kasih',
#  'beli pulang ini tidak ada paket internet',
#  'sudah ada nomor resi transfer tapi tetap tidak masuk',
#  'aku tidak tahu admin tidak tidak mengapa ada ini saja',
#  'kemarin tapi kenapa selalu ada sistem',
#  'baik jadi nanti saya pesanan yang benar dahulu ya baru nanti saya saya barang yang',
#  'apa sama aku',
#  'mohon maaf atas mohon informasi menunggu di mana dan tujuan mana terima kasih',
#  'apakah benar anda',
#  'hijau sesuai di apakah grab',
#  'ini ini ini saya saja kena',
#  'internet kuota nya bagaimana bagaimana bagaimana nya',
#  'di twitter kamu mereka bisa bisa',
#  'masih belum ada hari ini ini dalam ke depan bisa hahaha yang',
#  'bisa bantu tidak untuk informasi data drivernya',
#  'aku baru juga mau mulai dari sama teman eh dia malah dari dari',
#  'apakah kartu kartu bisa bisa di di',
#  'indosat lagi gangguan gangguan gangguan dari kemarin susah sinyal',
#  'kak mohon maaf atas hal tersebut untuk melakukan jaringan ditanggapi nomor telepon dan email anda melalui dm terima kasih',
#  'admin apakah bisa bisa kuota melalui mytelkomsel',
#  'nomor sangat apa yang',
#  'jp jp di kirim kurir dari tanggal sampai sekarang belum sampai untuk nomor pelanggan tidak bisa bisa sudah kak',
#  'grab yang gb dari besok beli lagi hanya rp',
#  'saya saya menerima paket saya karena rumah tidak siapa dan dan tapi paket saya jp belum sudah diterima tanpa ada nama penerima nya',
#  'kasih di mbak xl bantuan di mall yang sudah masalah nya',
#  'setuju sekali atau paling tidak kasih untuk langsung notifikasi itu itu bukannya tidak mau bantu tapi terlalu sering tidak jadinya',
#  'hari coba untuk nomor sampai sekarang tidak berhasil tidak padahal sudah tidak lalu lama tidak semakin ovo ya',
#  'baik baik apa saja yang harus saya saya untuk konfirmasi',
#  'tolong tadi disuruh kirim dm saat sudah kirim malah tidak di direspons bagaimana ini',
#  'bilang orang lain sampah nya si sampah',
#  'cs grab ada masalah yang yang saya yang',
#  'ketika mau cek tagihan token mengapa tidak bisa muncul pesan di',
#  'sms ini ini mengapa terus terpotong pulsa seperti ini',
#  'tidak padahal lalu sudah',
#  'admin minta informasi nomor nomor untuk nomor',
#  'semakin buruk langganan paket saja tidak karena sinyalnya yang semakin hari semakin parah bukti',
#  'ini mengapa sekali mengapa hari ini',
#  'baik terima respons dan informasinya terima',
#  'dari masa lalu hahaha',
#  'sudah saya dm kak mohon dicek',
#  'dm aku yang belum di dibalas',
#  'tolong tolong cek untuk paket itu tolong apa lalu untuk paket saya saya terima kasih',
#  'sinyal sekali tidak di yang tidak di di jelek sekali',
#  'halo mohon bantuannya ini mengapa tidak bisa bisa',
#  'sudah tetap saja tidak bisa sudah paket selalu pulsa saya sering sekali habis karena di pulsa bagaimana bagaimana mengapa sekarang im jelek sekali',
#  'grab di jogja sedang pada apa apa anjir masa untuk mencoba grabfood kali kali ada yang mengambil pesanan',
#  'indosat sinyal aku sebanyak sinyal sekali provider di di kasih',
#  'tidak kamu ini sampai di di dong hahaha',
#  'apakah bisa bisa tunai ke tabungan bank lain melalui atm tunai tunai bca kasih',
#  'hahaha saya cek gojek lebih kita coba yang besok pagi hahaha',
#  'mohon informasi mengapa saat mau check sangat transaksi pilihan pengiriman tidak ada grab ada padahal di ada ada',
#  'halo admin mau tanya tanya tanya kenapa ovo jam ini internet aku bisa bisa padahal bagus boleh tolong tolong',
#  'shopee jam malam',
#  'aku sudah ini sudah di nya dia',
#  'tidak lagi cinta',
#  'saat ini sudah sudah jogja belum',
#  'kuota itu saja jawabannya tidak membantu sama sekali',
#  'tolong cek dm dm admin kasih sebelumnya',
#  'bagaimana bagaimana dari tadi masa tidak ada satu pun driver yang bisa terima',
#  'yang yang telepon itu itu',
#  'apakah di bca di ada ada banking kasih',
#  'sudah tidak dm dm boleh di cek saja',
#  'kak maaf kak jadi tidak tidak mengenai bisa bisa nomor yang yang via dm agar admin bantu cek dahulu kasih',
#  'admin admin akun saya tidak login login',
#  'bagaimana tidak bisa bisa dm sudah sudah karena juga',
#  'kecewa sama sekali voucher flexi ktp itu tetap bayar ongkos tapi saat barang sampai sampai sampai pun tidak dapat',
#  'mahal si tapi sayang lambat lambat cinta',
#  'informasi android baru saja tanggal kemarin dan hampir semua aplikasi banking tidak tidak',
#  'kalau kalau kalau dimana pesanan barang yang yang sudah dibayar dan dan pakai kartu kartu pengembalian kartu bagaimana bagaimana',
#  'di tengah smartfren memang sudah baik',
#  'saya sudah tahu itu rekening bca nya email bagaimana untuk ktp nya',
#  'ketika beli ke',
#  'halo tolong tolong dm saya saya',
#  'sudah tapi sinyal tidak stabil selalu terus',
#  'terima hahaha yang ke ternyata yang di',
#  'tolong tolong resi jp tidak bisa tolong mau tahu barang saya sudah sampai mana',
#  'saya sangat kecewa dengan ini tolong tolong karena saya sudah bayar dari jam pagi tadi',
#  'kamu kamu aku aku',
#  'sudah saya dm tapi tapi belum belum ya',
#  'indosat mengapa pulsa saya pulsa',
#  'jawaban nya juga ini sudah sudah sudah',
#  'untuk sudah youtube terimakasih rp dapat gb',
#  'oke kasih nya saya saya saya admin',
#  'saya kirim uang mengapa tidak masuk padahal status berhasil dan saldo saya terpotong',
#  'kalau di tengah enak pagi ini kirim dari besok sampai',
#  'admin saya juga tidak dapat kode sudah untuk masuk aplikasi sendiri itu bagaimana bagaimana',
#  'malam ini ini kenapa mohon terima kasih',
#  'ini dan yang yang kartu di indonesia tapi katanya kasih ke luar luar',
#  'kalau kalau hanya jadi jadi seperti ini seperti ini sama daerah yang tidak ada tidak',
#  'tidak beli paket rp gb admin',
#  'om admin kemarin saya transfer dari rekening bri ke mandiri belum ribu rupiah sampai sekarang sekarang belum sampai tolong tolong',
#  'ada yang mau ini yang apakah nomor ini ini',
#  'saya salah admin isi resi seharusnya otomatis dari dari tapi saya malah sudah bayar melalui nomor nomor bisa tidak bisa',
#  'rekening dari siang sampai sekarang belum masuk juga terima',
#  'oh terima pak kalau saya pakai mengapa nya nya sangat internet dan jaringan dan juga',
#  'kasih gojek saya keluar dari dari dari',
#  'saya isi gopay belum masuk admin saya sangat kecewa sudah sudah lebih ini']

# %%
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu

# Tokenisasi teks formal pada data uji
y_test_seq = tokenizer_y.texts_to_sequences(df_test['formal'])
y_test_padded = pad_sequences(y_test_seq, maxlen=X_train_padded.shape[1])

# Tokenisasi teks formal pada data uji
references_test = tokenizer_y.sequences_to_texts(y_test_seq)

# Tokenisasi teks formal yang diprediksi pada data uji
hypotheses_test = tokenizer_y.sequences_to_texts(predicted_classes_test)


# Hitung BLEU score untuk setiap kalimat pada data uji
bleu_scores_test = [sentence_bleu([ref.split()], hyp.split()) for ref, hyp in zip(references_test, hypotheses_test)]

# Hitung BLEU score untuk seluruh corpus pada data uji
corpus_bleu_score_test = corpus_bleu([[ref.split()] for ref in references_test], [hyp.split() for hyp in hypotheses_test])

print("BLEU Scores for Each Sentence on Test Data:")
for i, score in enumerate(bleu_scores_test, start=1):
    print(f"Sentence {i}: {score:.4f}")

print("\nCorpus BLEU Score on Test Data:", corpus_bleu_score_test)
# Out:
# BLEU Scores for Each Sentence on Test Data:
# Sentence 1: 0.0000
# Sentence 2: 0.4666
# Sentence 3: 0.0000
# Sentence 4: 0.2326
# Sentence 5: 0.0000
# Sentence 6: 0.0000
# Sentence 7: 0.0000
# Sentence 8: 1.0000
# Sentence 9: 0.4301
# Sentence 10: 0.0000
# Sentence 11: 0.0000
# Sentence 12: 0.1851
# Sentence 13: 0.5361
# Sentence 14: 0.5411
# Sentence 15: 1.0000
# Sentence 16: 0.0000
# Sentence 17: 0.3247
# Sentence 18: 0.0000
# Sentence 19: 0.7515
# Sentence 20: 0.8948
# Sentence 21: 0.0000
# Sentence 22: 0.0000
# Sentence 23: 0.0000
# Sentence 24: 0.0000
# Sentence 25: 0.3124
# Sentence 26: 0.3439
# Sentence 27: 0.0000
# Sentence 28: 0.0000
# Sentence 29: 0.0000
# Sentence 30: 0.6004
# Sentence 31: 0.0000
# Sentence 32: 0.4740
# Sentence 33: 0.0000
# Sentence 34: 0.4172
# Sentence 35: 0.0000
# Sentence 36: 0.4671
# Sentence 37: 0.0000
# Sentence 38: 0.2474
# Sentence 39: 0.0000
# Sentence 40: 0.8187
# Sentence 41: 0.0000
# Sentence 42: 0.1467
# Sentence 43: 0.0000
# Sentence 44: 0.5204
# Sentence 45: 0.6130
# Sentence 46: 0.3067
# Sentence 47: 0.5314
# Sentence 48: 0.0000
# Sentence 49: 0.7349
# Sentence 50: 0.0000
# Sentence 51: 0.2619
# Sentence 52: 0.4402
# Sentence 53: 0.6687
# Sentence 54: 0.2223
# Sentence 55: 0.6435
# Sentence 56: 0.0000
# Sentence 57: 0.4412
# Sentence 58: 0.0000
# Sentence 59: 0.0000
# Sentence 60: 0.5463
# Sentence 61: 0.0000
# Sentence 62: 0.8187
# Sentence 63: 1.0000
# Sentence 64: 0.3176
# Sentence 65: 0.2895
# Sentence 66: 0.0000
# Sentence 67: 0.0000
# Sentence 68: 0.0000
# Sentence 69: 0.0000
# Sentence 70: 0.0000
# Sentence 71: 0.2886
# Sentence 72: 0.0000
# Sentence 73: 0.3553
# Sentence 74: 0.7349
# Sentence 75: 0.4248
# Sentence 76: 0.0000
# Sentence 77: 0.3339
# Sentence 78: 0.6812
# Sentence 79: 0.7071
# Sentence 80: 0.0000
# Sentence 81: 0.8187
# Sentence 82: 0.5283
# Sentence 83: 0.3144
# Sentence 84: 0.0000
# Sentence 85: 0.0000
# Sentence 86: 0.4111
# Sentence 87: 0.3549
# Sentence 88: 0.4429
# Sentence 89: 0.8091
# Sentence 90: 0.5946
# Sentence 91: 0.3674
# Sentence 92: 0.0000
# Sentence 93: 0.5029
# Sentence 94: 0.0000
# Sentence 95: 0.0000
# Sentence 96: 0.0000
# Sentence 97: 0.4238
# Sentence 98: 0.4238
# Sentence 99: 0.3106
# Sentence 100: 0.0000
# Sentence 101: 0.0000
# Sentence 102: 0.7083
# Sentence 103: 0.0000
# Sentence 104: 0.3866
# Sentence 105: 0.0000
# Sentence 106: 0.4594
# Sentence 107: 0.0000
# Sentence 108: 0.0000
# Sentence 109: 0.2768
# Sentence 110: 0.2987
# Sentence 111: 0.3863
# Sentence 112: 0.0000
# Sentence 113: 0.5864
# Sentence 114: 0.4692
# Sentence 115: 0.0000
# Sentence 116: 0.0000
# Sentence 117: 0.2627
# Sentence 118: 0.0000
# Sentence 119: 0.4238
# Sentence 120: 0.2369
# Sentence 121: 0.4702
# Sentence 122: 0.0000
# Sentence 123: 0.0000
# Sentence 124: 0.2925
# Sentence 125: 0.0000
# Sentence 126: 0.0000
# Sentence 127: 0.0000
# Sentence 128: 0.0000
# Sentence 129: 0.0000
# Sentence 130: 0.4552
# Sentence 131: 0.4548
# Sentence 132: 0.8742
# Sentence 133: 0.0000
# Sentence 134: 0.4671
# Sentence 135: 0.0000
# Sentence 136: 0.0000
# Sentence 137: 0.2328
# Sentence 138: 0.0000
# Sentence 139: 0.1978
# Sentence 140: 0.0000
# Sentence 141: 0.4740
# Sentence 142: 0.0000
# Sentence 143: 0.0000
# Sentence 144: 0.0000
# Sentence 145: 0.0000
# Sentence 146: 0.0000
# Sentence 147: 0.0000
# Sentence 148: 0.0000
# Sentence 149: 0.0000
# Sentence 150: 0.3072
# Sentence 151: 0.6065
# Sentence 152: 0.0000
# Sentence 153: 0.6432
# Sentence 154: 0.2953
# Sentence 155: 0.6158
# Sentence 156: 0.5061
# Sentence 157: 0.4111
# Sentence 158: 0.8187
# Sentence 159: 0.3825
# Sentence 160: 0.0000
# Sentence 161: 0.0000
# Sentence 162: 0.2684
# Sentence 163: 0.5555
# Sentence 164: 0.6148
# Sentence 165: 0.5254
# Sentence 166: 0.0000
# Sentence 167: 0.0000
# Sentence 168: 0.0000
# Sentence 169: 0.5347
# Sentence 170: 0.0000
# Sentence 171: 0.0000
# Sentence 172: 0.5874
# Sentence 173: 0.3831
# Sentence 174: 0.7598
# Sentence 175: 0.5978
# Sentence 176: 0.0000
# Sentence 177: 0.6161
# Sentence 178: 0.6981
# Sentence 179: 0.0000
# Sentence 180: 0.0000
# Sentence 181: 0.0000
# Sentence 182: 0.3861
# Sentence 183: 0.3583
# Sentence 184: 0.0000
# Sentence 185: 0.0000
# Sentence 186: 0.5339
# Sentence 187: 0.2469
# Sentence 188: 0.0000
# Sentence 189: 0.0000
# Sentence 190: 0.0000
# Sentence 191: 0.8067
# Sentence 192: 0.0000
# Sentence 193: 0.0000
# Sentence 194: 0.0000
# Sentence 195: 0.0000
# Sentence 196: 0.3646
# Sentence 197: 0.0000
# Sentence 198: 0.0000
# Sentence 199: 0.0000
# Sentence 200: 0.5697
# Sentence 201: 0.4376
# Sentence 202: 0.0000
# Sentence 203: 0.7349
# Sentence 204: 0.1945
# Sentence 205: 0.0000
# Sentence 206: 0.5384
# Sentence 207: 0.8107
# Sentence 208: 0.4347
# Sentence 209: 1.0000
# Sentence 210: 0.3907
# Sentence 211: 0.3366
# Sentence 212: 0.5373
# Sentence 213: 0.0000
# Sentence 214: 0.3810
# Sentence 215: 0.0000
# Sentence 216: 0.3850
# Sentence 217: 0.0000
# Sentence 218: 0.3198
# Sentence 219: 0.7598
# Sentence 220: 0.2300
# Sentence 221: 0.3448
# Sentence 222: 0.0000
# Sentence 223: 0.2879
# Sentence 224: 0.2732
# Sentence 225: 0.5424
# Sentence 226: 0.2595
# Sentence 227: 0.7788
# Sentence 228: 0.2782
# Sentence 229: 0.0000
# Sentence 230: 0.3641
# Sentence 231: 0.5578
# Sentence 232: 0.5969
# Sentence 233: 0.0000
# Sentence 234: 0.0000
# Sentence 235: 0.0000
# Sentence 236: 0.4720
# Sentence 237: 0.0000
# Sentence 238: 0.2691
# Sentence 239: 0.3299
# Sentence 240: 0.4137
# Sentence 241: 0.3373
# Sentence 242: 0.5373
# Sentence 243: 0.0000
# Sentence 244: 0.2900
# Sentence 245: 0.8091
# Sentence 246: 0.0000
# Sentence 247: 1.0000
# Sentence 248: 0.1976
# Sentence 249: 1.0000
# Sentence 250: 0.5739
# Sentence 251: 0.0000
# Sentence 252: 0.0000
# Sentence 253: 0.3479
# Sentence 254: 0.1673
# Sentence 255: 0.4974
# Sentence 256: 0.4191
# Sentence 257: 0.0000
# Sentence 258: 0.3097
# Sentence 259: 0.0000
# Sentence 260: 0.3803
# Sentence 261: 0.0000
# Sentence 262: 0.0000
# Sentence 263: 0.0000
# Sentence 264: 0.2996
# Sentence 265: 0.5875
# Sentence 266: 0.0000
# Sentence 267: 0.0000
# Sentence 268: 0.8633
# Sentence 269: 0.0000
# Sentence 270: 0.3548
# Sentence 271: 0.0000
# Sentence 272: 0.0000
# Sentence 273: 0.2816
# Sentence 274: 0.3165
# Sentence 275: 0.0000
# Sentence 276: 0.0000
# Sentence 277: 0.0000
# Sentence 278: 0.4336
# Sentence 279: 0.0000
# Sentence 280: 0.0000
# Sentence 281: 0.0000
# Sentence 282: 0.0000
# Sentence 283: 0.3782
# Sentence 284: 0.2283
# Sentence 285: 0.3929
# Sentence 286: 0.0000
# Sentence 287: 0.0000
# Sentence 288: 0.0000
# Sentence 289: 0.3303
# Sentence 290: 0.2125
# Sentence 291: 0.3768
# Sentence 292: 0.0000
# Sentence 293: 0.0000
# Sentence 294: 0.4480
# Sentence 295: 0.0000
# Sentence 296: 0.0000
# Sentence 297: 0.4637
# Sentence 298: 0.7506
# Sentence 299: 0.0000
# Sentence 300: 0.5507
# Sentence 301: 0.4480
# Sentence 302: 0.0000
# Sentence 303: 0.3868
# Sentence 304: 0.1805
# Sentence 305: 0.3499
# Sentence 306: 0.4684
# Sentence 307: 0.0000
# Sentence 308: 0.2432
# Sentence 309: 0.0000
# Sentence 310: 0.2530
# Sentence 311: 0.0000
# Sentence 312: 0.2778
# Sentence 313: 0.0000
# Sentence 314: 0.3457
# Sentence 315: 0.4925
# Sentence 316: 0.5134
# Sentence 317: 0.3901
# Sentence 318: 0.3907
# Sentence 319: 0.3926
# Sentence 320: 0.0000
# Sentence 321: 0.7401
# Sentence 322: 0.0000
# Sentence 323: 0.0000
# Sentence 324: 0.2464
# Sentence 325: 0.0000
# Sentence 326: 0.0000
# Sentence 327: 0.0000
# Sentence 328: 0.0000
# Sentence 329: 0.0000
# Sentence 330: 0.6163
# Sentence 331: 0.8762
# Sentence 332: 0.0000
# Sentence 333: 0.0000
# Sentence 334: 0.5834
# Sentence 335: 0.0000
# Sentence 336: 0.0000
# Sentence 337: 0.2199
# Sentence 338: 0.0000
# Sentence 339: 0.0000
# Sentence 340: 0.0000
# Sentence 341: 0.3985
# Sentence 342: 0.3146
# Sentence 343: 0.0000
# Sentence 344: 0.2305
# Sentence 345: 0.0000
# Sentence 346: 0.0000
# Sentence 347: 0.2543
# Sentence 348: 0.0000
# Sentence 349: 0.4035
# Sentence 350: 0.0000
# Sentence 351: 0.3985
# Sentence 352: 0.0000
# Sentence 353: 0.0000
# Sentence 354: 0.2937
# Sentence 355: 0.0000
# Sentence 356: 0.0000
# Sentence 357: 0.2288
# Sentence 358: 0.0000
# Sentence 359: 0.5789
# Sentence 360: 0.0000
# Sentence 361: 0.0000
# Sentence 362: 0.0000
# Sentence 363: 0.3226
#
# Corpus BLEU Score on Test Data: 0.3419894050110091

# %%
import pandas as pd

# Buat DataFrame
df_results = pd.DataFrame({
    'actual': df_test['formal'],
    'predicted': predicted_texts_test,
    'bleu score' : bleu_scores_test
})

# Tampilkan DataFrame
df_results
# Out:
#                                                 actual  \
# 0                   belum ada konfirmasi lagikah admin
# 1    matikan notifikasi yang itu kemarin juga sampa...
# 2    kak untuk keluhan telkomsel silahkan konfirmas...
# 3    percobaan penipuan lainnya potensi penipuan at...
# 4                      tolong sudah seperti ini kenapa
# ..                                                 ...
# 358          mengapa malah tambah lambat jaringan saya
# 359  halo  sedang ada masalah apakah mau membeli pa...
# 360  admin tolong periksa dm saya terkait keluhan p...
# 361  halo admin  paket  sudah sampai mana pelacakan...
# 362  hai  daftar transfer ke bank btn mengapa tidak...
#
#                                              predicted     bleu score
# 0                     ada konfirmasi lagi sedang admin  9.283143e-155
# 1    matikan tiba yang itu kemarin juga sampah seka...   4.665904e-01
# 2                  kak yang telkomsel yang kami di kak   3.221907e-78
# 3    atas nama jek sudah hadiah ada yang mau menggu...   2.326304e-01
# 4                       tolong tolong sudah mengapa ya  8.388266e-155
# ..                                                 ...            ...
# 358                mengapa tambah lambat jaringan saya   5.789301e-01
# 359  halo lagi ada lagi mau mau tidak mengapa tidak...  9.711930e-232
# 360     admin tolong cek dm saya terkait ke paket saya   5.929499e-78
# 361  admin paket halo tetapi sudah sampai mana dari...   4.661033e-78
# 362  daftar transfer ke bank kenapa terus kenapa ke...   3.226014e-01
#
# [363 rows x 3 columns]

# %%
df_results.to_excel('hasil_lstm.xlsx', index=False)
